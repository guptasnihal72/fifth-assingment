# %% [markdown]
# #Q1.	Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5 navigation links that are properly placed within the navigation bar using the CSS box model. The navigation items must change their text color on hover.
# -Ans ▶
# 	<!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         *{
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#         .container{
#             background-color: #6495ED;
#             width: 100%;
#             height: 50px;
#             font-family: 'Poppins', sans-serif;
#             box-sizing: border-box
#         }
#         .container ul{
#             display: flex;
#
#
#         }
#         .container ul li{
#             margin: 0 40px;
#             line-height: 50px;
#             list-style-type:none;
#
#         }
#         .container ul li a{
#             text-decoration: none;
#             color: white;
#             font-weight: bold;
#
#             padding:15px 15px;
#         }
#         .container ul li a:hover{
#             box-sizing: border-box;
#             background-color: #376dd0;
#             color: rgb(145, 136, 136);
#         }
#
#     </style>
# </head>
# <body>
#     <div class="container">
#         <ul>
#             <li><a href="">Home</a></li>
#             <li><a href="">About Us</a></li>
#             <li><a href="">Contact</a></li>
#             <li><a href="">Blog</a></li>
#             <li><a href="">Login</a></li>
#         </ul>
#     </div>
# </body>
# </html>

# %% [markdown]
# #Q2. Create a div centered with an image and paragraph similar to the image mentioned below.
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         .container{
#             justify-items: center;
#             margin: auto;
#             max-width: 320px;
#             width: 100%;
#             height: 250px;
#             border-radius: 10px;
#             background: linear-gradient(rgb(245, 196, 104),rgb(241, 241, 96));
#         }
#         .container img{
#             width: 100%;
#             margin-top: 10px;
#             /* padding-top: 10px; */
#             border-radius: 10px ;
#             border: 1px solid rgb(215, 221, 142);
#         }
#         .container p{
#             text-transform: capitalize;
#             margin: 10px 10px;
#         }
#         .container p span{
#             font-weight: bold;
#             font-size: 17px;
#         }
#         .container:hover{
#             /* background: transparent; */
#             cursor: pointer;
#             background-color: black;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTnPExKuUIE350uCWf7_wmo0LZwcXZEIjI4ig&s" alt="">
# <!—if image not show please change the image location and put the image in your machine-->
#         <p><span>Course name :</span> PW Skills Full Stack Web Development</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# #Q3. Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output.
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         *{
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#             font-family: sans-serif;
#         }.container{
#             border: 1px solid red;
#             width: 100%;
#             height: 100vh;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#         }.image{
#             border-radius: 10px;
#             max-width: 350px;
#             height: 250px;
#             width: 100%;
#             position: relative;
#             background: linear-gradient(rgb(53, 194, 218),rgb(94, 158, 237));
#         }.image img{
#          margin: 10px 0 0 20px;
#          border-radius: 10px;
#         }.content{
#             width: 100%;
#             height: 100%;
#             background-color: rgba(85, 81, 81,0.5);
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             flex-direction: column;
#             position: absolute;
#             top: 0;
#             left: 0;
#             opacity: 0;
#             transition: 0.6s;
#         }.content:hover{
#             opacity: 1.5;
#             border-radius: 10px;
#             cursor: pointer;
#         }.container p span{
#             text-align: center;
#             color:white;
#             font-size: 25px;
#             text-transform: uppercase;
#             font-weight: bold;
#         }.container p{
#             text-align: center;
#             color:white;
#             font-size: 15px;
#             text-transform: uppercase;
#             font-weight: bold;
#
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="image">
#             <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTnPExKuUIE350uCWf7_wmo0LZwcXZEIjI4ig&s" alt="">
#             <div class="content">
#             </div>
#             <p><span>Course name</span><br> full stack Development by pw skill</p>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# #Q4. Create a navigation bar similar to question 1. For each navigation item, use a different border style ?
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         *{
#             margin: 0;
#             padding: 0;
#         }
#         .main{
#             background-color: aqua;
#             max-height: 50px;
#             width: 100%;
#         }
#         .main ul{
#             display: flex;
#             line-height: 50px;
#         }
#         .main ul li{
#             max-width: 120px;
#             width: 100%;
#             /* border: 1px solid red; */
#             list-style-type: none;
#             margin-left: 40px;
#             text-align: center;
#             box-sizing: border-box;
#         }
#         .main ul li a{
#             border-bottom: 3px solid black;
#             padding: 5px;
#             text-decoration: none;
#             text-transform: uppercase;
#             color: black;
#         }
#         .main ul .first{
#             border-bottom: 3px dotted black;
#         }
#         .main ul .second{
#             border-bottom: 3px double black;
#         }
#         .main ul .third{
#             border-bottom: 3px groove  black;
#         }
#         .main ul .foruth{
#             border-bottom: 3px dashed  black;
#         }
#         .main ul .five{
#             border-bottom: 3px solid black;
#         }
#
#     </style>
# </head>
# <body>
#     <div class="main">
#         <ul>
#             <li><a href="" class="first">About Us</a></li>
#             <li><a href="" class="second">Home</a></li>
#             <li><a href="" class="third">Contact</a></li>
#             <li><a href="" class="foruth">Blog</a></li>
#             <li><a href="" class="five">login</a></li>
#         </ul>
#     </div>
#
# </body>
# </html>

# %% [markdown]
# #Q5. Create a simple webpage with an image and make the image circular using border-radius.
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         .main{
#             border: 1px solid red;
#             width: 100%;
#             height: 100vh;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             background-color: whitesmoke;
#         }
#         .img{
#             width:400px ;
#             height: 400px;
#             /* border: 1px solid red; */
#             background-color: yellow;
#             padding: 10px;
#             border-radius: 50%;
#         }
#         img{
#             width:400px ;
#             height: 400px;
#             /* border: 1px solid red; */
#             background-color: yellow;
#             padding: 10px;
#             border-radius: 50%;
#         }
#     </style>
# </head>
# <body>
#
#     <div class="main">
#             <img src="/img/images.jpg" alt="" aria-placeholder="this is image">
#     </div>
# </body>
# </html>

# %% [markdown]
# #Q6. Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font align center to the page, below the heading have an image of Google fonts and a paragraph about Google fonts in font “Montserrat” paragraph font style should be“montserrat” font?
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Blog about Google Fonts</title>
#     <link href="https://fonts.googleapis.com/css2?family=Oswald&family=Montserrat:wght@400&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Montserrat', sans-serif;
#             background-color: #f9f9f9;
#             margin: 0;
#             padding: 20px;
#             text-align: center;
#         }
#         h1 {
#             font-family: 'Oswald', sans-serif;
#             font-size: 3em;
#             margin-bottom: 20px;
#         }
#         p {
#             font-size: 1.2em;
#             line-height: 1.5;
#             max-width: 800px;
#             margin: 0 auto;
#         }
#         img {
#             max-width: 100%;
#             height: auto;
#             margin-bottom: 20px;
#         }
#     </style>
# </head>
# <body>
#
#     <h1>Google Fonts</h1>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/0e/Google_Fonts_logo.svg/2560px-Google_Fonts_logo.svg.png">
#     <p>
#         Google Fonts is a library of over 1,000 free licensed font families and APIs for conveniently using the fonts via CSS and Android. It provides a wide variety of styles and weights, making it easy for web designers and developers to find the perfect font for their projects. With Google Fonts, you can enhance the typography of your website and improve user experience without worrying about licensing issues.
#     </p>
#
# </body>
# </html>

# %% [markdown]
# #Q7. Create a simple website as mentioned in the below image. You can get the assets by visiting https:// pwskills.com/about-us ?
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         *{
#             margin: 0;
#             padding: 0;
#
#         }
#         body{
#             box-sizing: border-box;
#         }
#         .content{
#             width: 90%;
#             /* height: 100vh; */
#             border: 1px solid black;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             margin:5%;
#         }
#         .content1{
#             width: 90%;
#             /* border: 1px solid red; */
#             margin:20px
#         }
#         .content1 h2{
#             text-align: center;
#             font-size: 30px;
#             font-family: sans-serif;
#             text-transform: uppercase;
#         }
#         .content1 p{
#             text-align: justify;
#             font-size: 20px;
#             padding: 30px;
#             width: 90%;
#             margin: auto;
#         }
#         .content1 img{
#             display: flex;
#             margin: auto;
#             width: 90%;
#             border-radius: 20px;
#         }
#     </style>
# </head>
# <body>
#     <div class="content">
#         <div class="content1">
#             <h2>About Us</h2>
#             <p>PW Skills' mission is to permeate through every student/professional's outlook towards jobs and change their attitude and perspective from "How Can I Do It?" to "Of Course I Can Do It". We aim to do this by providing exceptional up skilling courses at affordable rates, while being tech-forward so anyone, anywhere can access and improve their ability to be successful in life.</p>
#             <img src="https://i.ytimg.com/vi/IJNbUBYSRgA/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLALBOdSA4m0anCr4TIhoY_Ty88XZw" alt="">
#         </div>
# </body>
# </html>

# %% [markdown]
# #Q8. Create a simple list of items as mentioned in the below image?
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         div{
#             border: 2px solid black;
#             width: 500px;
#         }
#         h1{
#             margin-left: 20px;
#         }
#         li{
#             list-style-type: lower-roman;
#         }
#     </style>
# </head>
# <body>
#     <div>
#         <h1>Requirements</h1>
#     <ul>
#         <li>System With minimum i3 Processor or better.</li>
#         <li>At least 4GB of RAM</li>
#         <li>working internet connection.</li>
#         <li>Dedication to learn</li>
#     </ul>
#     </div>
# </body>
# </html>
